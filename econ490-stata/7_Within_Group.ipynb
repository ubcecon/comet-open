// %% [markdown]
// # 7 Within Group Analysis
//
// Before we begin this lecture, let us open the dataset from last time.

// %%
clear *
cd "."

import delimited using "fake_data.csv", clear
// Out:
// C:\Users\paulc\Dropbox\Projects\Gitlab\econometrics\econ490-stata
//
// (9 vars, 2,861,772 obs)

// %% [markdown]
// When we're working on a particular project, it is important to know how to create variables that are computed within a group. For instance, we may be interested in the average wage of the individual workers across all different years, or enumerate the different observations within an individual.
//
// Stata provides functionality to easily compute such statistics. The key to this analysis is the pre-command `by`, and the only requisite to using this is to ensure data is sorted the correct way.

// %%
%browse
// Out:
//      +----------------------------------------------------------------------+
//   1. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        1 | 1999 |   M |     1944 |  55 |     1997 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               39975.01                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   2. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        1 | 2001 |   M |     1944 |  57 |     1997 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               278378.1                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   3. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2001 |   M |     1947 |  54 |     2001 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                18682.6                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   4. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2002 |   M |     1947 |  55 |     2001 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               293336.4                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   5. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2003 |   M |     1947 |  56 |     2001 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               111797.3                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   6. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        3 | 2005 |   M |     1951 |  54 |     2005 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               88351.67                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   7. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        3 | 2010 |   M |     1951 |  59 |     2005 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               46229.57                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   8. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        4 | 1997 |   M |     1952 |  45 |     1997 |      5 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               24911.03                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   9. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        4 | 2001 |   M |     1952 |  49 |     1997 |      5 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               9908.362                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  10. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        5 | 2009 |   M |     1954 |  55 |     1998 |      2 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               137207.3                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  11. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        5 | 2011 |   M |     1954 |  57 |     1998 |      2 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                5227.69                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  12. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        6 | 1995 |   M |     1954 |  41 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               53620.36                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  13. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        6 | 1999 |   M |     1954 |  45 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               28902.34                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  14. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        6 | 2000 |   M |     1954 |  46 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               58023.73                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  15. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        6 | 2003 |   M |     1954 |  49 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               132451.8                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  16. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        7 | 2007 |   M |     1958 |  49 |     2006 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               208644.8                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  17. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        7 | 2009 |   M |     1958 |  51 |     2006 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               330875.2                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  18. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        8 | 2007 |   M |     1959 |  48 |     1999 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               83872.56                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  19. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        8 | 2010 |   M |     1959 |  51 |     1999 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               29126.71                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  20. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        9 | 1997 |   M |     1962 |  35 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                 296822                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  21. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        9 | 2006 |   M |     1962 |  44 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               165501.4                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  22. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        9 | 2008 |   M |     1962 |  46 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               399610.9                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  23. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       10 | 1999 |   M |     1965 |  34 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                23455.5                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  24. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       10 | 2001 |   M |     1965 |  36 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               28081.39                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  25. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       10 | 2002 |   M |     1965 |  37 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                16827.1                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  26. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       11 | 1996 |   M |     1941 |  55 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               20401.53                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  27. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       11 | 1997 |   M |     1941 |  56 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               38037.63                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  28. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       12 | 2000 |   M |     1942 |  58 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               25679.33                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  29. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       12 | 2001 |   M |     1942 |  59 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               13154.44                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  30. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       12 | 2002 |   M |     1942 |  60 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               24012.12                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//
|       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                6896.02                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 191. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       64 | 1995 |   M |     1947 |  48 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               3665.528                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 192. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       64 | 2001 |   M |     1947 |  54 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               21983.13                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 193. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       65 | 2002 |   M |     1958 |  44 |     2001 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                 129714                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 194. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       65 | 2008 |   M |     1958 |  50 |     2001 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               129654.6                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 195. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 1997 |   M |     1958 |  39 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               54714.38                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 196. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 1999 |   M |     1958 |  41 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               190707.1                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 197. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2000 |   M |     1958 |  42 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               99077.64                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 198. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2001 |   M |     1958 |  43 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               332728.3                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 199. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2008 |   M |     1958 |  50 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               131804.3                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 200. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2009 |   M |     1958 |  51 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               528672.4                               |
//      +----------------------------------------------------------------------+

// %% [markdown]
// ## 7.1 Generating Variables using Standard Generate
//
// The command `generate` can be extended with the pre-command `by` as follows:

// %%
cap drop var_one 
by year: gen var_one = 1
// Out:
// not sorted
// r(5);
// r(5);

// %% [markdown]
// Wait... what is this message? It says that data is not sorted. Stata expects us to sort the data such that all observations corresponding to the same worker are next to each other. We can use the `sort` command as follows.

// %%
sort year

// %%
%browse
// Out:
//      +----------------------------------------------------------------------+
//   1. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   378258 | 1995 |   M |     1972 |  23 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               52968.54                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   2. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    92298 | 1995 |   F |     1963 |  32 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               10119.29                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   3. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    17301 | 1995 |   M |     1934 |  61 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                49260.6                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   4. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    29021 | 1995 |   M |     1949 |  46 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               352930.7                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   5. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   269652 | 1995 |   M |     1950 |  45 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               238648.5                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   6. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   171356 | 1995 |   M |     1968 |  27 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               7242.213                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   7. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   108381 | 1995 |   F |     1951 |  44 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               11913.33                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   8. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |     9393 | 1995 |   F |     1965 |  30 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               5909.894                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   9. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   443061 | 1995 |   M |     1973 |  22 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               36347.46                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  10. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   215870 | 1995 |   F |     1962 |  33 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                7516.67                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  11. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    19416 | 1995 |   M |     1954 |  41 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               22579.26                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  12. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   226180 | 1995 |   F |     1971 |  24 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               3620.219                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  13. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   203947 | 1995 |   M |     1959 |  36 |     1995 |      5 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               6051.753                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  14. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   195324 | 1995 |   M |     1969 |  26 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               92533.93                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  15. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    45529 | 1995 |   M |     1965 |  30 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               49827.99                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  16. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |     5027 | 1995 |   M |     1961 |  34 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               14604.17                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  17. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    96897 | 1995 |   M |     1950 |  45 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               71655.16                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  18. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   227428 | 1995 |   M |     1955 |  40 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               75690.05                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  19. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   196051 | 1995 |   M |     1961 |  34 |     1995 |      5 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                                8802.69                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  20. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    87949 | 1995 |   M |     1949 |  46 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               154851.1                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  21. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   269403 | 1995 |   M |     1973 |  22 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               159151.1                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//  22. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |
|       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               16021.04                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 180. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   402023 | 1995 |   M |     1975 |  20 |     1995 |      1 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               18672.12                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 181. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    17607 | 1995 |   M |     1955 |  40 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               35208.74                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 182. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   419849 | 1995 |   M |     1973 |  22 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               41970.74                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 183. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   113712 | 1995 |   M |     1968 |  27 |     1995 |      1 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               46315.11                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 184. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    17608 | 1995 |   M |     1955 |  40 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               34060.32                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 185. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    22719 | 1995 |   M |     1956 |  39 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               43541.78                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 186. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   250523 | 1995 |   F |     1961 |  34 |     1995 |      1 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               64543.08                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 187. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   342826 | 1995 |   M |     1972 |  23 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               113484.2                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 188. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   260571 | 1995 |   M |     1963 |  32 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               205959.6                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 189. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   393473 | 1995 |   F |     1976 |  19 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               122900.9                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 190. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   519642 | 1995 |   M |     1976 |  19 |     1995 |      2 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               11950.38                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 191. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   146296 | 1995 |   F |     1969 |  26 |     1995 |      2 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               84522.78                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 192. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   304965 | 1995 |   F |     1954 |  41 |     1995 |      4 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               10810.72                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 193. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   192715 | 1995 |   M |     1966 |  29 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               180309.3                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 194. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    35900 | 1995 |   F |     1963 |  32 |     1995 |      3 |       1 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               83118.43                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 195. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   426044 | 1995 |   M |     1969 |  26 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               31637.86                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 196. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   160037 | 1995 |   M |     1937 |  58 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               282807.2                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 197. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   469771 | 1995 |   M |     1970 |  25 |     1995 |      1 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               7289.904                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 198. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   120390 | 1995 |   M |     1959 |  36 |     1995 |      5 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               67065.86                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 199. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   413780 | 1995 |   M |     1957 |  38 |     1995 |      4 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               20351.02                               |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 200. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    80367 | 1995 |   F |     1968 |  27 |     1995 |      3 |       0 |
//      |----------------------------------------------------------------------|
//      |                               earnings                               |
//      |                               30578.08                               |
//      +----------------------------------------------------------------------+

// %%
cap drop var_one 
by year: gen var_one = 1

// %% [markdown]
// Now the code works! We can run the whole thing in one step by writing `bysort` instead of `by`.

// %%
sort workerid year //Let's sort the data back as it was originally to revert back

// %%
cap drop var_one 
bysort year: gen var_one = 1

// %% [markdown]
// Awesome. Although the variable we have created is not interesting by any means, it takes the value of 1 everywhere. We didn't even need to work within groups to do something like this, could've just written `gen var_one=1` and call it a day!

// %% [markdown]
// You may not be aware but Stata records the observation number as a hidden variable (formally, a scalar) called `_n` and the total number of observations as `_N`.

// %%
cap drop obs_number 
gen obs_number = _n 

cap drop tot_obs
gen tot_obs = _N

// %%
%browse
// Out:
//      +----------------------------------------------------------------------+
//   1. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   247834 | 1995 |   M |     1949 |  46 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    10224.97     |          1     |           1     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   2. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    61219 | 1995 |   M |     1963 |  32 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    20904.56     |          1     |           2     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   3. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    33731 | 1995 |   F |     1964 |  31 |     1995 |      3 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    61507.25     |          1     |           3     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   4. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   861979 | 1995 |   M |     1975 |  20 |     1995 |      1 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    37619.32     |          1     |           4     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   5. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   211635 | 1995 |   M |     1955 |  40 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |      130355     |          1     |           5     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   6. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   292584 | 1995 |   M |     1959 |  36 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |
|       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    16240.13     |          1     |         183     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 184. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    60108 | 1995 |   M |     1959 |  36 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    115247.3     |          1     |         184     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 185. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   272354 | 1995 |   F |     1968 |  27 |     1995 |      4 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    7996.474     |          1     |         185     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 186. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    84101 | 1995 |   M |     1960 |  35 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    146422.9     |          1     |         186     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 187. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    54393 | 1995 |   F |     1965 |  30 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    28060.43     |          1     |         187     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 188. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    82114 | 1995 |   F |     1955 |  40 |     1995 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    141644.3     |          1     |         188     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 189. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   371018 | 1995 |   M |     1958 |  37 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    147078.3     |          1     |         189     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 190. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   188922 | 1995 |   M |     1956 |  39 |     1995 |      1 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    80031.09     |          1     |         190     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 191. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   549589 | 1995 |   M |     1952 |  43 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    34276.11     |          1     |         191     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 192. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   370333 | 1995 |   M |     1972 |  23 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     18606.8     |          1     |         192     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 193. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   368355 | 1995 |   F |     1955 |  40 |     1995 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    85977.57     |          1     |         193     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 194. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   434260 | 1995 |   F |     1941 |  54 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    44502.58     |          1     |         194     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 195. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   310569 | 1995 |   M |     1958 |  37 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    109405.3     |          1     |         195     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 196. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   416615 | 1995 |   M |     1974 |  21 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     72874.2     |          1     |         196     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 197. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |    41932 | 1995 |   M |     1961 |  34 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    16834.18     |          1     |         197     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 198. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   309212 | 1995 |   M |     1940 |  55 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    97576.48     |          1     |         198     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 199. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   186502 | 1995 |   M |     1941 |  54 |     1995 |      2 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    34857.06     |          1     |         199     |     2861772     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 200. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |   251655 | 1995 |   M |     1963 |  32 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    39176.03     |          1     |         200     |     2861772     |
//      +----------------------------------------------------------------------+

// %% [markdown]
// As expected, this is sensitive to the way that data is sorted! The cool thing is that whenever we use the pre-command `by` the scalars `_n` and `_N` record the observation number and total number of observations for *every group* separately.

// %%
cap drop obs_number 
bysort workerid: gen obs_number = _n 

cap drop tot_obs
bysort workerid: gen tot_obs = _N

// %%
%browse
// Out:
//      +----------------------------------------------------------------------+
//   1. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        1 | 1999 |   M |     1944 |  55 |     1997 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    39975.01     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   2. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        1 | 2001 |   M |     1944 |  57 |     1997 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    278378.1     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   3. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2002 |   M |     1947 |  55 |     2001 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    293336.4     |          1     |           1     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   4. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2001 |   M |     1947 |  54 |     2001 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     18682.6     |          1     |           2     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   5. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        2 | 2003 |   M |     1947 |  56 |     2001 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    111797.3     |          1     |           3     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   6. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        3 | 2010 |   M |     1951 |  59 |     2005 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    46229.57     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   7. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        3 | 2005 |   M |     1951 |  54 |     2005 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    88351.67     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   8. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        4 | 1997 |   M |     1952 |  45 |     1997 |      5 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    24911.03     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//   9. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |        4 | 2001 |   M |     1952 |  49 |     1997 |      5 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    9908.362     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
//
| workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       60 | 2003 |   M |     1961 |  42 |     2001 |      2 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    32201.01     |          1     |           1     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 183. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       60 | 2008 |   M |     1961 |  47 |     2001 |      2 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    7622.609     |          1     |           2     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 184. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       60 | 2004 |   M |     1961 |  43 |     2001 |      2 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    11872.98     |          1     |           3     |           3     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 185. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       61 | 1997 |   M |     1962 |  35 |     1996 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     27190.9     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 186. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       61 | 2009 |   M |     1962 |  47 |     1996 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    57530.68     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 187. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       62 | 1996 |   M |     1962 |  34 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     16436.7     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 188. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       62 | 1997 |   M |     1962 |  35 |     1995 |      5 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    35701.79     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 189. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       63 | 2001 |   M |     1964 |  37 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    106893.7     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 190. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       63 | 2009 |   M |     1964 |  45 |     1995 |      2 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |     6896.02     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 191. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       64 | 1995 |   M |     1947 |  48 |     1995 |      4 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    3665.528     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 192. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       64 | 2001 |   M |     1947 |  54 |     1995 |      4 |       1 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    21983.13     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 193. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       65 | 2008 |   M |     1958 |  50 |     2001 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    129654.6     |          1     |           1     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 194. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       65 | 2002 |   M |     1958 |  44 |     2001 |      4 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |      129714     |          1     |           2     |           2     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 195. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2001 |   M |     1958 |  43 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    332728.3     |          1     |           1     |           6     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 196. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2009 |   M |     1958 |  51 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    528672.4     |          1     |           2     |           6     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 197. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2008 |   M |     1958 |  50 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    131804.3     |          1     |           3     |           6     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 198. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 1999 |   M |     1958 |  41 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    190707.1     |          1     |           4     |           6     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 199. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 2000 |   M |     1958 |  42 |     1995 |      3 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    99077.64     |          1     |           5     |           6     |
//      +----------------------------------------------------------------------+
//
//      +----------------------------------------------------------------------+
// 200. | workerid | year | sex | birth_~r | age | start_~r | region | treated |
//      |       66 | 1997 |   M |     1958 |  39 |     1995 |      1 |       0 |
//      |-----------------+----------------+-----------------------------------|
//      |    earnings     |    var_one     |    obs_nu~r     |     tot_obs     |
//      |    54714.38     |          1     |           6     |           6     |
//      +----------------------------------------------------------------------+

// %% [markdown]
// As we can see, some workers are observed only 2 times in the data; whereas other workers are observed 8 times. By knowing (and recoding in a variable) the times a worker has been observed, we can do some different analysis based on this information. For example, in some cases you might be interested in keeping only workers who are observed across all time periods.

// %% [markdown]
// ## 7.2 Generating Variables using Extended Generate (egen)
//
// The command `egenerate` is used whenever we want to create variables that require some functions (e.g. mean, standard deviation, min).  The basic syntax works as follows:
//
// ```
//  bysort groupvar: egen new_var = function() , options
// ```
//
// Let's see an example where we create a new variable called `avg_earnings` which is the `mean` of earnings for every worker.

// %%
cap drop avg_earnings
bysort workerid: egen avg_earnings = mean(earnings)

// %%
cap drop total_earnings
bysort workerid: egen total_earnings = total(earnings)

// %% [markdown]
// By definition, these commands will create variables that use information across different observations. You can check the list of available functions by writing `help egen`.
//
// In this documentation, you will notice that there are some functions that do not allow for `by`. For example, suppose we want to create the total sum across different variables in the same row. We'll sum some arbitrary variables (i.e. there is no meaning in the variable we are creating) for the sake of explanation.

// %%
cap drop sum_of_vars
egen sum_of_vars = rowtotal(start_year region treated)

// %% [markdown]
// How is this different than creating `gen sum_of_vars = start_year +  region + treated`. The answer lies in the missing observations. If you sum any number with a missing (`.`), then the sum will be also missing. The function `rowtotal()` only sums non-missing values in our variables. In most situations, this is what we're looking for.

// %% [markdown]
// Notice that we can use `by` with a list of variables, not necessarily a unique variable.

// %%
cap drop regionyear_earnings
bysort year region : egen regionyear_earnings = total(earnings)

// %% [markdown]
// ## 7.3 Collapsing the Data
//
// We can aso compute statistics at some group level with the `collapse` command. However, these changes are irreversible. For example, suppose we want to create a dataset at the region-year level using information in the current dataset.
//
// First, we decide which statistics we want to keep from the original dataset. For the sake of explanation, let's suppose we want to keep average earnings, the variance of earnings, and the total employment.
//
// The syntax is
//
// ```
//  collapse (statistic1) new_name = existing_variable (statistic2) new_name2 = existing_variable2 ... , by(group)
// ```
//
//
// We write

// %%
collapse (mean) avg_earnings = earnings (sd) sd_earnings = earnings (count) tot_emp = earnings , by(region year)

// %%
%browse
// Out:
//      +-----------------------------------------------+
//      | year   region   avg_ea~s   sd_ear~s   tot_emp |
//      |-----------------------------------------------|
//   1. | 1995        1    67284.3   144739.1     28143 |
//   2. | 1996        1   65632.83   139990.2     31078 |
//   3. | 1997        1    67655.4   144867.9     33583 |
//   4. | 1998        1   67836.61   113053.4     35696 |
//   5. | 1999        1   69703.96   130300.2     37443 |
//      |-----------------------------------------------|
//   6. | 2000        1   70636.84   153549.7     39559 |
//   7. | 2001        1   75025.45   212302.6     40722 |
//   8. | 2002        1   72514.41   148687.6     41353 |
//   9. | 2003        1   75885.88   134078.5     41242 |
//  10. | 2004        1      73384   145342.2     41339 |
//      |-----------------------------------------------|
//  11. | 2005        1   72555.81   135471.6     41927 |
//  12. | 2006        1   72048.02     152768     42859 |
//  13. | 2007        1   73201.65   139596.8     42168 |
//  14. | 2008        1   74975.35   244015.6     42420 |
//  15. | 2009        1   77620.29   356074.8     41508 |
//      |-----------------------------------------------|
//  16. | 2010        1    75462.8   164038.6     40511 |
//  17. | 2011        1   75207.74   129948.6     38502 |
//  18. | 1995        2    66190.1   117372.4     26581 |
//  19. | 1996        2   68069.03   149648.5     28682 |
//  20. | 1997        2   68224.64   128714.4     30307 |
//      |-----------------------------------------------|
//  21. | 1998        2   68943.63   133498.9     31964 |
//  22. | 1999        2   69618.63   168674.8     33583 |
//  23. | 2000        2    71425.4   134765.7     34429 |
//  24. | 2001        2    72271.2   132342.7     35286 |
//  25. | 2002        2   72097.36   146888.4     35851 |
//      |-----------------------------------------------|
//  26. | 2003        2   77591.75   162594.3     34546 |
//  27. | 2004        2   73530.06   153642.2     35105 |
//  28. | 2005        2    71321.6   162014.8     35708 |
//  29. | 2006        2   71002.66   139390.7     36606 |
//  30. | 2007        2   72971.89   164133.1     36569 |
//      |-----------------------------------------------|
//  31. | 2008        2   72449.97   136443.5     36546 |
//  32. | 2009        2   74370.66   135029.1     35794 |
//  33. | 2010        2   74886.38   153100.7     35161 |
//  34. | 2011        2   74763.57   145359.3     33276 |
//  35. | 1995        3   64923.38   130556.7     21516 |
//      |-----------------------------------------------|
//  36. | 1996        3   64691.85   208054.4     23484 |
//  37. | 1997        3   65300.58   112418.2     25032 |
//  38. | 1998        3   67277.41   122532.4     26979 |
//  39. | 1999        3   68236.85   127385.4     28403 |
//  40. | 2000        3   67877.86   121106.9     30644 |
//      |-----------------------------------------------|
//  41. | 2001        3   70567.73   117235.7     31277 |
//  42. | 2002        3   70245.67   129402.6     31924 |
//  43. | 2003        3   74984.59   136067.5     31416 |
//  44. | 2004        3   72173.13   135296.1     32299 |
//  45. | 2005        3   70294.16   150864.2     33617 |
//      |-----------------------------------------------|
//  46. | 2006        3   69992.58   138194.8     34191 |
//  47. | 2007        3   71961.21   129862.2     34061 |
//  48. | 2008        3   71941.55   156814.4     33868 |
//  49. | 2009        3   73070.45   131299.6     33236 |
//  50. | 2010        3   74557.63   170217.2     33197 |
//      |-----------------------------------------------|
//  51. | 2011        3   75450.45   142370.8     30902 |
//  52. | 1995        4   63071.85   109039.2     27271 |
//  53. | 1996        4   62737.48   111585.4     29598 |
//  54. | 1997        4   64112.85     110085     31630 |
//  55. | 1998        4   65824.41   114692.6     32649 |
//      |-----------------------------------------------|
//  56. | 1999        4   66779.38   174003.1     34665 |
//  57. | 2000        4   66504.84   113566.6     35389 |
//  58. | 2001        4   70406.24   140761.9     37174 |
//  59. | 2002        4   69810.66   156517.5     37924 |
//  60. | 2003        4    73096.6   124012.1     37131 |
//      |-----------------------------------------------|
//  61. | 2004        4    70817.4   140540.8     37698 |
//  62. | 2005        4   68821.28   124218.6     38505 |
//  63. | 2006        4   67580.55   115328.1     39413 |
//  64. | 2007        4   70851.72     129617     39156 |
//  65. | 2008        4   70735.16   125012.5     39854 |
//      |-----------------------------------------------|
//  66. | 2009        4   71709.08   133171.1     38871 |
//  67. | 2010        4    73278.8   148844.8     38536 |
//  68. | 2011        4    73557.6   143087.3     37407 |
//  69. | 1995        5   67649.22     130281     21769 |
//  70. | 1996        5   67451.16   207551.5     23473 |
//      |-----------------------------------------------|
//  71. | 1997        5    70813.8   352413.3     24816 |
//  72. | 1998        5   72157.93   167477.6     26512 |
//  73. | 1999        5   71631.07   145928.6     27846 |
//  74. | 2000        5   71171.02   130451.6     29535 |
//  75. | 2001        5   74526.13   163653.3     30053 |
//      |-----------------------------------------------|
//  76. | 2002        5   77129.93     238141     30275 |
//  77. | 2003        5   77722.84   142464.7     30461 |
//  78. | 2004        5   78432.54   340692.5     30804 |
//  79. | 2005        5   74635.09   148769.4     31398 |
//  80. | 2006        5   73752.73   145977.4     32327 |
//      |-----------------------------------------------|
//  81. | 2007        5   77562.43   205593.7     32648 |
//  82. | 2008        5   82318.05    1075188     31916 |
//  83. | 2009        5   77594.48   161854.1     31731 |
//  84. | 2010        5   80170.91   328381.4     31462 |
//  85. | 2011        5   82794.25   509268.3     29782 |
//      +-----------------------------------------------+

// %% [markdown]
// As you can see above, there's no way to recover the information we previously had. However, we may be interesting in analysis this type of datasets at a group level. We may s
